# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas_profiling
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv("test.csv")
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
pandas_profiling.ProfileReport(df, title="Report Data Test").to_file("output test.html")
# Out:
# HBox(children=(IntProgress(value=0, description='Summarize dataset', max=25, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='Generate report structure', max=1, style=ProgressStyle(descri…
# C:\Users\chsagala\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\visualisation\plot.py:154: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("RdBu"))
#   cmap.set_bad(cmap_bad)
# HBox(children=(IntProgress(value=0, description='Render HTML', max=1, style=ProgressStyle(description_width='i…
# HBox(children=(IntProgress(value=0, description='Export report to file', max=1, style=ProgressStyle(descriptio…

# %%
# !pip install facets-overview
# Out:
# Collecting facets-overview
#   Downloading https://files.pythonhosted.org/packages/df/8a/0042de5450dbd9e7e0773de93fe84c999b5b078b1f60b4c19ac76b5dd889/facets_overview-1.0.0-py2.py3-none-any.whl
# Collecting protobuf>=3.7.0 (from facets-overview)
#   Downloading https://files.pythonhosted.org/packages/6b/2e/28425c709c26525998be0b7a91c4090c87c38a1a9644fd43fefaea2e16c0/protobuf-3.13.0-cp37-cp37m-win_amd64.whl (1.0MB)
# Requirement already satisfied: pandas>=0.22.0 in c:\programdata\anaconda3\lib\site-packages (from facets-overview) (1.0.5)
# Requirement already satisfied: numpy>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from facets-overview) (1.16.5)
# Requirement already satisfied: six>=1.9 in c:\programdata\anaconda3\lib\site-packages (from protobuf>=3.7.0->facets-overview) (1.12.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from protobuf>=3.7.0->facets-overview) (41.4.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.22.0->facets-overview) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.22.0->facets-overview) (2019.3)
# Installing collected packages: protobuf, facets-overview
# Successfully installed facets-overview-1.0.0 protobuf-3.13.0

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
features = ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
train_data = pd.read_csv(
    "train.csv",
    names=features,
    sep=r'\s*,\s*',
    engine='python',
    na_values="?")

# %%
# Display the Dive visualization for the training data.
from IPython.core.display import display, HTML

jsonstr = train_data.to_json(orient='records')
HTML_TEMPLATE = """
        <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
        <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
        <facets-dive id="elem" height="600"></facets-dive>
        <script>
          var data = {jsonstr};
          document.querySelector("#elem").data = data;
        </script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#         <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#         <facets-dive id="elem" height="600"></facets-dive>
#         <script>
#           var data = [{"PassengerId":"Survived","Survived":"Pclass","Pclass":"Name","Name":"Sex","Sex":"Age","Age":"SibSp","SibSp":"Parch","Parch":"Ticket","Ticket":"Fare","Fare":"Cabin","Cabin":"Embarked","Embarked":null},{"PassengerId":"0","Survived":"3","Pclass":"\"Braund","Name":"Mr. Owen Harris\"","Sex":"male","Age":"22","SibSp":"1","Parch":"0","Ticket":"A\/5 21171","Fare":"7.25","Cabin":null,"Embarked":"S"},{"PassengerId":"1","Survived":"1","Pclass":"\"Cumings","Name":"Mrs. John Bradley (Florence Briggs Thayer)\"","Sex":"female","Age":"38","SibSp":"1","Parch":"0","Ticket":"PC 17599","Fare":"71.2833","Cabin":"C85","Embarked":"C"},{"PassengerId":"1","Survived":"3","Pclass":"\"Heikkinen","Name":"Miss. Laina\"","Sex":"female","Age":"26","SibSp":"0","Parch":"0","Ticket":"STON\/O2. 3101282","Fare":"7.925","Cabin":null,"Embarked":"S"},{"PassengerId":"1","Survived":"1","Pclass":"\"Futrelle","Name":"Mrs. Jacques Heath (Lily May Peel)\"","Sex":"female","Age":"35","SibSp":"1","Parch":"0","Ticket":"113803","Fare":"53.1","Cabin":"C123","Embarked":"S"},{"PassengerId":"0","Survived":"3","Pclass":"\"Allen","Name":"Mr. William Henry\"","Sex":"male","Age":"35","SibSp":"0","Parch":"0","Ticket":"373450","Fare":"8.05","Cabin":null,"Embarked":"S"},{"PassengerId":"0","Survived":"3","Pclass":"\"Moran","Name":"Mr. James\"","Sex":"male","Age":null,"SibSp":"0","Parch":"0","Ticket":"330877","Fare":"8.4583","Cabin":null,"Embarked":"Q"},{"PassengerId":"0","Survived":"1","Pclass":"\"McCarthy","Name":"Mr. Timothy J\"","Sex":"male","Age":"54","SibSp":"0","Parch":"0","Ticket":"17463","Fare":"51.8625","Cabin":"E46","Embarked":"S"},{"PassengerId":"0","Survived":"3","Pclass":"\"Palsson","Name":"Master. Gosta Leonard\"","Sex":"male","Age":"2","SibSp":"3","Parch":"1","Ticket":"349909","Fare":"21.075","Cabin":null,"Embarked":"S"},{"PassengerId":"1","Survived":"3","Pclass":"\"Johnson","Name":"Mrs. Oscar W (Elisabeth Vilhelmina Berg)\"","Sex":"female","Age":"27","SibSp":"0","Parch":"2","Ticket":"347742","Fare":"11.1333","Cabin":null,"Embarked":"S"},{"PassengerId":"1","Survived":"2","Pclass":"\"Nasser","Name":"Mrs. Nicholas (Adele Achem)\"","Sex":"female","Age":"14","SibSp":"1","Parch":"0","Ticket":"237736","Fare":"30.0708","Cabin":null,"Embarked":"C"},{"PassengerId":"1","Survived":"3","Pclass":"\"Sandstrom","Name":"Miss. Marguerite Rut\"","Sex":"female","Age":"4","SibSp":"1","Parch":"1","Ticket":"PP 9549","Fare":"16.7","Cabin":"G6","Embarked":"S"},{"PassengerId":"1","Survived":"1","Pclass":"\"Bonnell","Name":"Miss. Elizabeth\"","Sex":"female","Age":"58","SibSp":"0","Parch":"0","Ticket":"113783","Fare":"26.55","Cabin":"C103","Embarked":"S"},{"PassengerId":"0","Survived":"3","Pclass":"\"Saundercock","Name":"Mr. William Henry\"","Sex":"male","Age":"20","SibSp":"0","Parch":"0","Ticket":"A\/5. 2151","Fare":"8.05","Cabin":null,"Embarked":"S"},{"PassengerId":"0","Survived":"3","Pclass":"\"Andersson","Name":"Mr. Anders Johan\"","Sex":"male","Age":"39","SibSp":"1","Parch":"5","Ticket":"347082","Fare":"31.275","Cabin":null,"Embarked":"S"},{"PassengerId":"0","Survived":"3","Pclass":"\"Vestrom","Name":"Miss. Hulda Amanda Adolfina\"","Sex":"female","Age":"14","SibSp":"0","Parch":"0","Ticket":"350406","Fare":"7.8542","Cabin":null,"Embarked":"S"},{"PassengerId":"1","Survived":"2","Pclass":"\"Hewlett","Name":"Mrs. (Mary D Kingcome) \"","Sex":"female","Age":"55","SibSp":"0","Parch":"0","Ticket":"248706","Fare":"16","Cabin":null,"Embarked":"S"},{"PassengerId":"0","Survived":"3","Pclass":"\"Rice","Name":"Master. Eugene\"","Sex":"male","Age":"2","SibSp":"4","Parch":"1","Ticket":"382652","Fare":"29.125","Cabin":null,"Embarked":"Q"},{"PassengerId":"1","Survived":"2","Pclass":"\"Williams","Name":"Mr. Charles Eugene\"","Sex":"male","Age":null,"SibSp":"0","Parch":"0","Ticket":"244373","Fare":"13","Cabin":null,"Embarked":"S"},{"PassengerId":"0","Survived":"3","Pclass":"\"Vander Planke","Name":"Mrs. Julius (Emelia Maria Vandemoortele)\"","Sex":"female","Age":"31","SibSp":"1","Parch":"0"," ...

# %%
html.
